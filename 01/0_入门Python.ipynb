# %% [markdown]
# # 先让我们来回答几个问题
#
# ## 为什么要学Python？
# - 这个时代最流行也最必需要掌握的语言
# - 语言简洁、开发效率高、可移植性强，可与其他编程语言衔接
# - 应用广泛，无论是数据处理、机器学习、还是Web开发
# - ... 太多理由了
#
# ## 学习的路径是什么？
#
# 让我们从最基础的操作开始，
# - 学习语法：
# 理解变量间的赋值、基本的数据类型、条件与循环语句、函数的用法...
# - 规范代码：变量和函数的命名...
# - 深挖相关数据分析的应用。
#
#
# ## 我听明白了，就是会了吗？
#
# 得练练练！
# 动脑子！
# 实战！
#
#
# ## 学了有什么用？
# - 掌握计算机编程思维，融会贯通不同语言。
# - 可能是为了，在GPT时代，更好的活下去吧。

# %% [markdown]
# ---

# %% [markdown]
# # 让我们从 Jupter Notebook 开始
# 对。就是现在你看到的这个。
#
# ## 为什么叫这个名字？
# Fernando Pérez 创始人最初的想法是建立一个Ju （Julia）、Py （Python）和 R 三种科学运算语言的计算工具平台。现在，Jupyter 能够几乎支持所有语言，将软件代码、计算输出、解释文档、多媒体资源等都整合在了一起。
#
# ## 为什么用Jupyter Notebook?
#
# 我真的很想说，好用就完事了。
#
# Jupyter在我看来最特殊的地方在于将代码块状化，以此带来了即强的交互感和丰富的结果可视化。这大大降低了学习代码的学习成本。

# %% [markdown]
# ---

# %% [markdown]
# # 第一个Python程序

# %%
# This is my first example
import time # import time package

# Print: How many seconds have elapsed from 0:00 on January 1, 1970 to the present
print(time.time())

if 10-9 > 0:
  # use indentation
  print("10 is greater than 9")
# Out:
# 1687275883.3087873
# 10 is greater than 9

# %% [markdown]
# # 接下来让我们从简明Python教程开始

# %% [markdown]
# ## Numbers小练习

# %%
# try the following mathematical calculations and guess what is happening: ((3 / 2)), ((3 // 2)), ((3 % 2)), ((3**2)).

# Floating point division
result_float_div = 3 / 2
print(result_float_div)

# Integer division
result_int_div = 3 // 2
print(result_int_div)

# Modulo operation
result_mod = 3 % 2
print(result_mod)

# Power operation
result_pow = 3**2
print(result_pow)
# Out:
# 1.5
# 1
# 1
# 9

# %%
# Calculate the average of the following sequences of numbers: (2, 4), (4, 8, 9), (12, 14/6, 15)

# Averages
average_1 = (2 + 4) / 2
print(average_1)

average_2 = (4 + 8 + 9) / 3
print(average_2)

average_3 = (12 + (14/6) + 15) / 3
print(average_3)
# Out:
# 3.0
# 7.0
# 9.777777777777779

# %%
# The volume of a sphere is given by (4/3 * pi * r^3). Calculate the volume of a sphere of radius 5. Suggestion: create a variable named "pi" with the value of 3.1415.

# Sphere volume
pi = 3.1415
r = 5
volume = (4/3) * pi * r**3
print(volume)
# Out:
# 523.5833333333333

# %% [markdown]
# ## String 小练习

# %%
# Initialize the string "abc" on a variable named "s":

s = "abc"

# Use a function to get the length of the string.

length = len(s)
print(length)

# Write the necessary sequence of operations to transform the string "abc" in "aaabbbccc". Suggestion: Use string concatenation and string indexes.

s = "abc"
s = s[0]*3 + s[1]*3 + s[2]*3
print(s)
# Out:
# 3
# aaabbbccc

# %%
# Initialize the string "aaabbbccc" on a variable named "s":

s = "aaabbbccc"

# Use a function that allows you to find the first occurence of "b" in the string, and the first occurence of "ccc".

first_b = s.find('b')
first_ccc = s.find('ccc')
print(first_b)
print(first_ccc)

# Use a function that allows you to replace all occurences of "a" to "X", and then use the same function to change only the first occurence of "a" to "X".

s_replace_all = s.replace('a', 'X')
s_replace_first = s.replace('a', 'X', 1)
print(s_replace_all)
print(s_replace_first)
# Out:
# 3
# 6
# XXXbbbccc
# Xaabbbccc

# %%
# Starting from the string "aaa bbb ccc", what sequences of operations do you need to arrive at the following strings? You can use the "replace" function.

# "AAA BBB CCC"

# "AAA bbb CCC"

s = "aaa bbb ccc"
s_upper = s.upper()
print(s_upper)

s_part_upper = s.replace('aaa', 'AAA').replace('ccc', 'CCC')
print(s_part_upper)
# Out:
# AAA BBB CCC
# AAA bbb CCC

# %% [markdown]
# ## if 小练习

# %%
# Use the modulo operator (%) to check which of the following numbers is even or odd: (1, 5, 20, 60/7).

# Suggestion: the remainder of (x/2) is always zero when (x) is even.

# Checking for evenness or oddness
numbers = [1, 5, 20, 60/7]

for num in numbers:
    if num % 2 == 0:
        print(f"{num} is even.")
    elif num % 2 == 1:
        print(f"{num} is odd.")
    else:
        print(f"{num} is not an integer.")
# Out:
# 1 is odd.
# 5 is odd.
# 20 is even.
# 8.571428571428571 is not an integer.

# %% [markdown]
# ## For 小练习

# %%
# Create a function "add" that receives a list as parameter and returns the sum of all elements in the list.
# Use the "for" loop to iterate over the elements of the list.

# Function to add all elements in a list
def add(lst):
    total = 0
    for num in lst:
        total += num
    return total


print(add([1,2,3,4,5]))
# Out:
# 15

# %%
# Create a function that receives a list as parameter and returns the maximum value in the list.
# As you iterate over the list you may want to keep the maximum value found so far in order
# to keep comparing it with the next elements of the list.

# Function to find the maximum value in a list
def find_max(lst):
    max_value = lst[0]
    for num in lst:
        if num > max_value:
            max_value = num
    return max_value


print(find_max([1,2,3,4,5]))
# Out:
# 5

# %%
# Modify the previous function such that it returns a list with the first element being the maximum value
# and the second being the index of the maximum value in the list.
# Besides keeping the maximum value found so far, you also need to keep the position where it occurred.

# Function to find the maximum value and its index in a list
def find_max_index(lst):
    max_value = lst[0]
    max_index = 0
    for i, num in enumerate(lst):
        if num > max_value:
            max_value = num
            max_index = i
    return [max_value, max_index]

print(find_max_index([1,2,3,4,5]))
# Out:
# [5, 4]

# %%
# Implement a function that returns the reverse of a list received as parameter.
# You may create an empty list and keep adding the values in reversed order as they come from the original list.
# Check what you can do with lists at https://docs.python.org/3/tutorial/datastructures.html#more-on-lists.

# Function to reverse a list
def reverse(lst):
    reversed_list = []
    for num in lst[::-1]:
        reversed_list.append(num)
    return reversed_list

print(reverse([1,2,3,4,5]))
# Out:
# [5, 4, 3, 2, 1]

# %%
# Make the function "is_sorted" that receives a list as parameter and returns True if the list
# is sorted in ascending order. For instance [1, 2, 2, 3] is ordered while [1, 2, 3, 2] is not.
# Suggestion: you have to compare a number in the list with the next one, so you can use indexes
# or you need to keep the previous number in a variable as you iterate over the list.

# Function to check if a list is sorted in ascending order
def is_sorted(lst):
    for i in range(len(lst)-1):
        if lst[i] > lst[i+1]:
            return False
    return True

print(is_sorted([1,2,4,5,3]))
# Out:
# False

# %%
# Implement the function "is_sorted_dec" which is similar to the previous one but all items must
# be sorted by decreasing order.

# Function to check if a list is sorted in descending order
def is_sorted_dec(lst):
    for i in range(len(lst)-1):
        if lst[i] < lst[i+1]:
            return False
    return True

print(is_sorted([5,4,3,2,1]))
# Out:
# False

# %%
# Implement the "has_duplicates" function which verifies if a list has duplicate values.
# You may have to use two "for" loops, where for each value you have to check for
# duplicates on the rest of the list.

# Function to check if a list has duplicates
def has_duplicates(lst):
    for i in range(len(lst)):
        for j in range(i+1, len(lst)):
            if lst[i] == lst[j]:
                return True
    return False

print(has_duplicates([5,4,4,3,2,1]))
# Out:
# True

# %% [markdown]
# ## while 的小练习

# %%
# Implement a function that receives a number as parameter and prints, in decreasing order,
# which numbers are even and which are odd, until it reaches 0.
def print_even_odd(n):
    while n >= 0:
        if n % 2 == 0:
            print(f"{n} is even.")
        else:
            print(f"{n} is odd.")
        n -= 1

print_even_odd(10)
# Out:
# 10 is even.
# 9 is odd.
# 8 is even.
# 7 is odd.
# 6 is even.
# 5 is odd.
# 4 is even.
# 3 is odd.
# 2 is even.
# 1 is odd.
# 0 is even.
